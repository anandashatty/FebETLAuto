# %%
import pandas as pd
df = pd.read_csv("emp.csv")

# %%
df
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10   66959
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   73247
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10   67458
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
sorted_values= df.sort_values(by =['deptno','salary'], ascending=[True,False])

# %%
sorted_values
# Out:
#      eno               ename         doj  deptno  salary
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 20  1021      Prakash Pillai  2022-12-11      10   73569
# 18  1019          Meera Nair  2020-09-17      10   73506
# 44  1045        Pankaj Joshi  2022-06-10      10   70445
# 38  1039          Ajit Reddy  2022-04-18      10   69399
# 32  1033         Suresh Jain  2021-12-01      10   69234
# 6   1007         Vijay Singh  2022-07-08      10   67458
# 0   1001        Arjun Sharma  2022-01-15      10   66959
# 26  1027       Harshit Kumar  2022-08-16      10   66535
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 19  1020         Krishna Rao  2023-10-02      20   70187
# 21  1022  Aishwarya Deshmukh  2021-07-25      20   69746
# 27  1028       Kanika Thakur  2020-01-10      20   67752
# 45  1046          Suman Iyer  2023-04-28      20   67751
# 1   1002         Priya Patel  2023-03-22      20   67387
# ...

# %%
sort_by_index= df.sort_index(ascending = False)

# %%
sort_by_index
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10   66959
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   73247
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10   67458
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
df
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10   66959
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   73247
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10   67458
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
df.sort_values(by =['deptno','salary'], ascending=[True,False], inplace=True)

# %%
df
# Out:
#      eno               ename         doj  deptno  salary
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 20  1021      Prakash Pillai  2022-12-11      10   73569
# 18  1019          Meera Nair  2020-09-17      10   73506
# 44  1045        Pankaj Joshi  2022-06-10      10   70445
# 38  1039          Ajit Reddy  2022-04-18      10   69399
# 32  1033         Suresh Jain  2021-12-01      10   69234
# 6   1007         Vijay Singh  2022-07-08      10   67458
# 0   1001        Arjun Sharma  2022-01-15      10   66959
# 26  1027       Harshit Kumar  2022-08-16      10   66535
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 19  1020         Krishna Rao  2023-10-02      20   70187
# 21  1022  Aishwarya Deshmukh  2021-07-25      20   69746
# 27  1028       Kanika Thakur  2020-01-10      20   67752
# 45  1046          Suman Iyer  2023-04-28      20   67751
# 1   1002         Priya Patel  2023-03-22      20   67387
# ...

# %%
df = pd.read_csv("emp.csv")
grouped_data = df.groupby('deptno')['eno'].count().reset_index()
grouped_data.rename(columns ={'eno':'count_of_emp'}, inplace=True)
grouped_data
# Out:
#    deptno  count_of_emp
# 0      10             9
# 1      20             9
# 2      30             8
# 3      40             8
# 4      50             8
# 5      60             8

# %%
df = pd.read_csv("emp.csv")
grouped_agg = df.groupby('deptno')['salary'].agg(['count','min','max','sum','mean']).reset_index()
grouped_agg
# Out:
#    deptno  count    min    max     sum          mean
# 0      10      9  66535  73569  617018  68557.555556
# 1      20      9  61487  74625  608870  67652.222222
# 2      30      8  60933  70986  536809  67101.125000
# 3      40      8  67801  73247  560495  70061.875000
# 4      50      8  62497  78005  570135  71266.875000
# 5      60      8  59843  71892  525908  65738.500000

# %%
grouped_agg.rename(columns ={'count':'count_of_salary','min':'min_of_salary','max':'max_of_salary','sum':'sum_of_salary','mean':'avg_of_salary'}, inplace=True)
grouped_agg
# Out:
#    deptno  count_of_salary  min_of_salary  max_of_salary  sum_of_salary  \
# 0      10                9          66535          73569         617018
# 1      20                9          61487          74625         608870
# 2      30                8          60933          70986         536809
# 3      40                8          67801          73247         560495
# 4      50                8          62497          78005         570135
# 5      60                8          59843          71892         525908
#
#    avg_of_salary
# 0   68557.555556
# 1   67652.222222
# 2   67101.125000
# 3   70061.875000
# 4   71266.875000
# 5   65738.500000

# %%
df = pd.read_csv("emp.csv")

col_rename = {'count':'count_of_salary','min':'min_of_salary','max':'max_of_salary','sum':'sum_of_salary'}
grouped_aggg.rename(columns =col_rename, inplace=True)
grouped_aggg
# Out:
#    deptno  count_of_salary  min_of_salary  max_of_salary  sum_of_salary
# 0      10                9          66535          74363         631468
# 1      20                9          61487          74625         608870
# 2      30                8          60933          70986         536809
# 3      40                8          63559          73247         550225
# 4      50                8          62497          78005         570135
# 5      60                8          59843          71892         525908

# %%
df = pd.read_csv("emp.csv")
col_rename = {'count':'count_of_salary','min':'min_of_salary','max':'max_of_salary','sum':'sum_of_salary'}
df.groupby('deptno')['salary'].agg(['count','min','max','sum']).reset_index().rename(columns =col_rename, inplace=True)

# %%
df = pd.read_csv("emp.csv")
df.sort_values(by ='deptno')
grp_data= df.groupby('deptno')['salary'].agg(['count','min','max','sum'])
col_rename = {'count':'count_of_salary','min':'min_of_salary','max':'max_of_salary','sum':'sum_of_salary'}
grp_data = grp_data.rename(columns=col_rename)
grp_data
# Out:
#         count_of_salary  min_of_salary  max_of_salary  sum_of_salary
# deptno
# 10                    9          66535          73569         617018
# 20                    9          61487          74625         608870
# 30                    8          60933          70986         536809
# 40                    8          67801          73247         560495
# 50                    8          62497          78005         570135
# 60                    8          59843          71892         525908

# %%
df = pd.read_csv("emp.csv")
where_cls = df['deptno']==10
dept_10_rec = df[where_cls]
dept_10_rec
# Out:
#      eno           ename         doj  deptno  salary
# 0   1001    Arjun Sharma  2022-01-15      10   66959
# 6   1007     Vijay Singh  2022-07-08      10   66959
# 12  1013  Shivani Sharma  2022-09-13      10   66959
# 18  1019      Meera Nair  2020-09-17      10   66959
# 20  1021  Prakash Pillai  2022-12-11      10   73569
# 26  1027   Harshit Kumar  2022-08-16      10   66535
# 32  1033     Suresh Jain  2021-12-01      10   69234
# 38  1039      Ajit Reddy  2022-04-18      10   69399
# 44  1045    Pankaj Joshi  2022-06-10      10   70445
